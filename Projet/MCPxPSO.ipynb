# %%
import numpy as np
import os
import time
from math import ceil

# %%
class Benchmark:
    def __init__(self, file_path, benchmark_type):
        self.file_path = file_path
        self.benchmark_type = benchmark_type
        self.subsets, self.universe_size, self.num_subsets = self.read_benchmark()

    def read_benchmark(self):
        """Lecture d'un benchmark MCP à partir d'un fichier texte"""
        with open(self.file_path, "r") as file:
            lines = file.readlines()

        #Lecture de la 1er ligne m et n
        m, n = map(int, lines[0].split())
        #Lecture des lignes de coûts a sauter 
        cost_lines_to_skip = ceil(n / 12) if self.benchmark_type == "4" else ceil(n / 15)
        subset_start_index = 1 + cost_lines_to_skip  # Start of subset coverage data
        
        data_lines = lines[subset_start_index:]
        row_to_subsets = {}
        index = 0
        
        #generate dictionary of subsets for each row
        for row in range(1, m + 1):
            num_subsets = int(data_lines[index].strip())
            index += 1

            subsets = []
            while len(subsets) < num_subsets:
                subsets.extend(map(int, data_lines[index].split()))
                index += 1

            row_to_subsets[row] = subsets

        #Inverse
        #generate dictionary of rows for each subset
        subset_to_rows = {}
        for row, subsets in row_to_subsets.items():
            for subset in subsets:
                if subset not in subset_to_rows:
                    subset_to_rows[subset] = []
                subset_to_rows[subset].append(row)

        return subset_to_rows, m, n

# %%
class PSO_MCP:
    def __init__(self, benchmark, num_particles=100, num_iterations=50, c1=1.5, c2=2, w=1, vmax=10, early_stop=30):
        self.benchmark = benchmark
        self.num_particles = num_particles
        self.num_iterations = num_iterations
        self.c1 = c1
        self.c2 = c2
        self.w = w
        self.vmax = vmax
        self.early_stop = early_stop
        self.k = ceil(benchmark.universe_size * 2 / 3)  # Define k

    def fitness_func(self, solution):
        """Évalue une solution en mesurant le nombre d'éléments couverts"""
        covered_elements = set()
        for idx, selected in enumerate(solution):
            if selected and idx in self.benchmark.subsets:
                covered_elements.update(self.benchmark.subsets[idx])
        return len(covered_elements), len(covered_elements) / self.benchmark.universe_size

    def run(self):
        """Exécute l'optimisation PSO"""
        np.random.seed(42)
        particles = np.zeros((self.num_particles, self.benchmark.universe_size), dtype=int)
        
        for i in range(self.num_particles):
            ones_indices = np.random.choice(self.benchmark.universe_size, self.k, replace=False)
            particles[i, ones_indices] = 1
        
        velocities = np.zeros((self.num_particles, self.benchmark.universe_size))
        personal_best = particles.copy()
        personal_best_scores = np.array([self.fitness_func(p)[1] for p in particles])
        global_best_idx = np.argmax(personal_best_scores)
        global_best = personal_best[global_best_idx].copy()
        global_best_covered, global_best_score = self.fitness_func(global_best)
        
        best_scores = []
        no_improvement = 0
        start_time = time.time()

        for iteration in range(self.num_iterations):
            for i in range(self.num_particles):
                velocities[i] = self.update_velocity_binary(velocities[i], particles[i], personal_best[i], global_best)
                particles[i] = self.binary_update(particles[i], velocities[i])
                
                num_covered, score = self.fitness_func(particles[i])
                
                if score > personal_best_scores[i]:
                    personal_best[i] = particles[i].copy()
                    personal_best_scores[i] = score
                
                if score > global_best_score:
                    global_best = particles[i].copy()
                    global_best_covered, global_best_score = num_covered, score
                    no_improvement = 0  # Reset early stop counter

            best_scores.append(global_best_score)
            print(f"Iteration {iteration+1}/{self.num_iterations} - Covered: {global_best_covered}, Score: {global_best_score * 100:.4f} %")

            if no_improvement >= self.early_stop:
                print(f"Arrêt anticipé après {iteration+1} itérations.")
                break
            
            no_improvement += 1

        execution_time = time.time() - start_time
        print(f"Optimisation terminée en {execution_time:.2f} sec - Meilleure couverture: {global_best_covered}, Score final: {global_best_score *100 :.4f} %")
        
        return global_best, global_best_covered, global_best_score, execution_time

        # # Tracer l'évolution du score
        # plt.plot(best_scores, label='Best Score')
        # plt.xlabel('Iterations')
        # plt.ylabel('Score')
        # plt.title('Évolution du score pendant l'optimisation')
        # plt.legend()
        # plt.show()

    def update_velocity_binary(self, velocity, particle, personal_best, global_best):
        """Binary PSO velocity update using discrete difference"""
        r1, r2 = np.random.rand(len(particle)), np.random.rand(len(particle))
        velocity = (self.w * velocity +
                    self.c1 * r1 * (personal_best != particle).astype(int) +
                    self.c2 * r2 * (global_best != particle).astype(int))
        return np.clip(velocity, -self.vmax, self.vmax)

    def enforce_k_constraint(self, particle):
        """S'assure que le vecteur binaire a exactement k éléments activés"""
        if np.sum(particle) != self.k:
            ones = np.where(particle == 1)[0]
            zeros = np.where(particle == 0)[0]

            if len(ones) > self.k:
                np.random.shuffle(ones)
                particle[ones[self.k:]] = 0  # Désactive les surplus
            elif len(ones) < self.k:
                np.random.shuffle(zeros)
                particle[zeros[:(self.k - len(ones))]] = 1  # Active des zéros pour atteindre k
        return particle
    

    def binary_update(self, particle, velocity):
        """Mise à jour des particules en utilisant la transformation sigmoïde"""
        prob = 1 / (1 + np.exp(-velocity))
        updated_particle = (np.random.rand(*particle.shape) < prob).astype(int)
        return self.enforce_k_constraint(updated_particle)

# %%
def experiment(benchmark_files, benchmark_folder, type):
    """Exécute l'optimisation PSO sur un benchmark"""

    results = []

    for file in benchmark_files:
        file_path = os.path.join(benchmark_folder, file)
        benchmark = Benchmark(file_path, type)
        if type == "4":
            # Iterations: 50, W: 0.5, c1: 2.5, c2: 2.5, Vmax: 6, Particles: 100
            pso = PSO_MCP(benchmark, num_particles=100, num_iterations=50, c1=2.5, c2=2.5, w=0.5, vmax=6)
        elif type == "A":
            # Iterations: 50, W: 0.4, c1: 1, c2: 1.0, Vmax: 6, Particles: 50
            pso = PSO_MCP(benchmark, num_particles=50, num_iterations=50, c1=1, c2=1.0, w=0.4, vmax=6)
        elif type == "B":
            pso = PSO_MCP(benchmark, num_particles=50, c2=1, w=0.5)
        elif type == "C":
            # Iterations: 50, W: 0.4, c1: 1, c2: 1.0, Vmax: 6, Particles: 50
            pso = PSO_MCP(benchmark, num_particles=50, num_iterations=50, c1=1, c2=1.0, w=0.4, vmax=6)
        else:
            print(f"Type de benchmark inconnu: {type}")

        print(f"\n Exécution de PSO sur {file}...")
        best_solution, best_covered, best_score, exec_time = pso.run()
        results.append((file, best_solution, best_covered, best_score, exec_time))
    return results

# %%
def run_all_benchmarks():
    """Exécute l'optimisation PSO sur tous les benchmarks"""
    benchmark_folders = ["Benchmark/4", "Benchmark/A", "Benchmark/B", "Benchmark/C"]
    all_results = []

    for benchmark_folder in benchmark_folders:
        print(f"\n Dossier de benchmarks: {benchmark_folder}")
        benchmark_files = sorted([f for f in os.listdir(benchmark_folder) if f.endswith(".txt")])
        results = experiment(benchmark_files, benchmark_folder, benchmark_folder[-1])
        
        for file, _, best_cov, score, time in results:  # Fix tuple unpacking
            all_results.append((benchmark_folder, file, best_cov, score, time))

    print("\n Résumé des résultats après toutes les exécutions :")
    for folder, file, best_cov, score, time in all_results:
        print(f"{folder}/{file}: Couvert = {best_cov}, Score = {score *100 :.4f} % , Temps = {time:.2f}s")

# %%
def run_one_benchmark(benchmark_folder):
    """Exécute l'optimisation PSO sur un benchmark spécifique"""
    benchmark_files = sorted([f for f in os.listdir(benchmark_folder) if f.endswith(".txt")])
    results = experiment(benchmark_files, benchmark_folder, benchmark_folder[-1])
    
    print("\n Résumé des résultats après toutes les exécutions :")
    for file, _, best_cov, score, time in results:  # Remove 'folder' (incorrect variable)
        print(f"{file}: Couvert = {best_cov}, Score = {score *100 :.4f} % , Temps = {time:.2f}s")

# %%
def run_one_file(path):
    benchmark = Benchmark(path, path.split("Benchmark/")[1][0])
    pso = PSO_MCP(benchmark)
    print(f"\n Exécution de PSO sur {path}...")
    best_solution, best_covered, best_score, exec_time = pso.run()
    print(f"\n Résumé des résultats :")
    print(f"{path}: Couvert = {best_covered}, Score = {best_score *100:.4f} % , Temps = {exec_time:.2f}s")

# %%
if __name__ == "__main__":
    #run only one set
    # run_one_file("Benchmark/4/scp41.txt")

    #run all sets in one benchmark
    # run_one_benchmark("Benchmark/A")

    #run all benchmarks
    run_all_benchmarks()
# Out:
#  Dossier de benchmarks: Benchmark/4
#
#  Exécution de PSO sur scp41.txt...
# Iteration 1/50 - Covered: 194, Score: 97.0000 %
# Iteration 2/50 - Covered: 195, Score: 97.5000 %
# Iteration 3/50 - Covered: 195, Score: 97.5000 %
# Iteration 4/50 - Covered: 195, Score: 97.5000 %
# Iteration 5/50 - Covered: 195, Score: 97.5000 %
# Iteration 6/50 - Covered: 195, Score: 97.5000 %
# Iteration 7/50 - Covered: 195, Score: 97.5000 %
# Iteration 8/50 - Covered: 195, Score: 97.5000 %
# Iteration 9/50 - Covered: 195, Score: 97.5000 %
# Iteration 10/50 - Covered: 195, Score: 97.5000 %
# Iteration 11/50 - Covered: 195, Score: 97.5000 %
# Iteration 12/50 - Covered: 195, Score: 97.5000 %
# Iteration 13/50 - Covered: 195, Score: 97.5000 %
# Iteration 14/50 - Covered: 195, Score: 97.5000 %
# Iteration 15/50 - Covered: 195, Score: 97.5000 %
# Iteration 16/50 - Covered: 195, Score: 97.5000 %
# Iteration 17/50 - Covered: 195, Score: 97.5000 %
# Iteration 18/50 - Covered: 195, Score: 97.5000 %
# Iteration 19/50 - Covered: 195, Score: 97.5000 %
# Iteration 20/50 - Covered: 195, Score: 97.5000 %
# Iteration 21/50 - Covered: 195, Score: 97.5000 %
# Iteration 22/50 - Covered: 195, Score: 97.5000 %
# Iteration 23/50 - Covered: 195, Score: 97.5000 %
# Iteration 24/50 - Covered: 195, Score: 97.5000 %
# Iteration 25/50 - Covered: 195, Score: 97.5000 %
# Iteration 26/50 - Covered: 195, Score: 97.5000 %
# Iteration 27/50 - Covered: 195, Score: 97.5000 %
# Iteration 28/50 - Covered: 195, Score: 97.5000 %
# Iteration 29/50 - Covered: 195, Score: 97.5000 %
# Iteration 30/50 - Covered: 195, Score: 97.5000 %
# Iteration 31/50 - Covered: 196, Score: 98.0000 %
# Iteration 32/50 - Covered: 196, Score: 98.0000 %
# Iteration 33/50 - Covered: 196, Score: 98.0000 %
# Iteration 34/50 - Covered: 196, Score: 98.0000 %
# Iteration 35/50 - Covered: 196, Score: 98.0000 %
# Iteration 36/50 - Covered: 196, Score: 98.0000 %
# Iteration 37/50 - Covered: 196, Score: 98.0000 %
# Iteration 38/50 - Covered: 196, Score: 98.0000 %
# Iteration 39/50 - Covered: 196, Score: 98.0000 %
# Iteration 40/50 - Covered: 196, Score: 98.0000 %
# Iteration 41/50 - Covered: 196, Score: 98.0000 %
# Iteration 42/50 - Covered: 196, Score: 98.0000 %
# Iteration 43/50 - Covered: 196, Score: 98.0000 %
# Iteration 44/50 - Covered: 196, Score: 98.0000 %
# Iteration 45/50 - Covered: 196, Score: 98.0000 %
# Iteration 46/50 - Covered: 196, Score: 98.0000 %
# Iteration 47/50 - Covered: 196, Score: 98.0000 %
# Iteration 48/50 - Covered: 196, Score: 98.0000 %
# Iteration 49/50 - Covered: 196, Score: 98.0000 %
# Iteration 50/50 - Covered: 196, Score: 98.0000 %
# Optimisation terminée en 0.63 sec - Meilleure couverture: 196, Score final: 98.0000 %
#
#  Exécution de PSO sur scp410.txt...
# Iteration 1/50 - Covered: 189, Score: 94.5000 %
# Iteration 2/50 - Covered: 189, Score: 94.5000 %
# Iteration 3/50 - Covered: 189, Score: 94.5000 %
# Iteration 4/50 - Covered: 189, Score: 94.5000 %
# Iteration 5/50 - Covered: 194, Score: 97.0000 %
# Iteration 6/50 - Covered: 194, Score: 97.0000 %
# Iteration 7/50 - Covered: 194, Score: 97.0000 %
# Iteration 8/50 - Covered: 194, Score: 97.0000 %
# Iteration 9/50 - Covered: 194, Score: 97.0000 %
# Iteration 10/50 - Covered: 194, Score: 97.0000 %
# Iteration 11/50 - Covered: 194, Score: 97.0000 %
# Iteration 12/50 - Covered: 194, Score: 97.0000 %
# Iteration 13/50 - Covered: 194, Score: 97.0000 %
# Iteration 14/50 - Covered: 194, Score: 97.0000 %
# Iteration 15/50 - Covered: 194, Score: 97.0000 %
# Iteration 16/50 - Covered: 194, Score: 97.0000 %
# Iteration 17/50 - Covered: 194, Score: 97.0000 %
# Iteration 18/50 - Covered: 194, Score: 97.0000 %
# Iteration 19/50 - Covered: 194, Score: 97.0000 %
# Iteration 20/50 - Covered: 194, Score: 97.0000 %
# Iteration 21/50 - Covered: 194, Score: 97.0000 %
# Iteration 22/50 - Covered: 194, Score: 97.0000 %
# Iteration 23/50 - Covered: 194, Score: 97.0000 %
# Iteration 24/50 - Covered: 194, Score: 97.0000 %
# Iteration 25/50 - Covered: 194, Score: 97.0000 %
# Iteration 26/50 - Covered: 194, Score: 97.0000 %
# Iteration 27/50 - Covered: 194, Score: 97.0000 %
# Iteration 28/50 - Covered: 194, Score: 97.0000 %
# Iteration 29/50 - Covered: 194, Score: 97.0000 %
# Iteration 30/50 - Covered: 194, Score: 97.0000 %
# Iteration 31/50 - Covered: 194, Score: 97.0000 %
# Iteration 32/50 - Covered: 194, Score: 97.0000 %
# Iteration 33/50 - Covered: 194, Score: 97.0000 %
# Iteration 34/50 - Covered: 194, Score: 97.0000 %
# Iteration 35/50 - Covered: 194, Score: 97.0000 %
# Arrêt anticipé après 35 itérations.
# Optimisation terminée en 0.40 sec - Meilleure couverture: 194, Score final: 97.0000 %
#
#  Exécution de PSO sur scp42.txt...
# Iteration 1/50 - Covered: 191, Score: 95.5000 %
# Iteration 2/50 - Covered: 192, Score: 96.0000 %
# Iteration 3/50 - Covered: 192, Score: 96.0000 %
# Iteration 4/50 - Covered: 192, Score: 96.0000 %
# Iteration 5/50 - Covered: 192, Score: 96.0000 %
# Iteration 6/50 - Covered: 192, Score: 96.0000 %
# Iteration 7/50 - Covered: 192, Score: 96.0000 %
# Iteration 8/50 - Covered: 192, Score: 96.0000 %
# Iteration 9/50 - Covered: 192, Score: 96.0000 %
# Iteration 10/50 - Covered: 192, Score: 96.0000 %
# Iteration 11/50 - Covered: 192, Score: 96.0000 %
# Iteration 12/50 - Covered: 192, Score: 96.0000 %
# Iteration 13/50 - Covered: 192, Score: 96.0000 %
# Iteration 14/50 - Covered: 192, Score: 96.0000 %
# Iteration 15/50 - Covered: 192, Score: 96.0000 %
# Iteration 16/50 - Covered: 192, Score: 96.0000 %
# Iteration 17/50 - Covered: 192, Score: 96.0000 %
# Iteration 18/50 - Covered: 193, Score: 96.5000 %
# Iteration 19/50 - Covered: 193, Score: 96.5000 %
# Iteration 20/50 - Covered: 193, Score: 96.5000 %
# Iteration 21/50 - Covered: 193, Score: 96.5000 %
# Iteration 22/50 - Covered: 193, Score: 96.5000 %
# Iteration 23/50 - Covered: 193, Score: 96.5000 %
# Iteration 24/50 - Covered: 193, Score: 96.5000 %
# Iteration 25/50 - Covered: 193, Score: 96.5000 %
# Iteration 26/50 - Covered: 193, Score: 96.5000 %
# Iteration 27/50 - Covered: 193, Score: 96.5000 %
# Iteration 28/50 - Covered: 193, Score: 96.5000 %
# Iteration 29/50 - Covered: 193, Score: 96.5000 %
# Iteration 30/50 - Covered: 193, Score: 96.5000 %
# Iteration 31/50 - Covered: 193, Score: 96.5000 %
# Iteration 32/50 - Covered: 193, Score: 96.5000 %
# Iteration 33/50 - Covered: 193, Score: 96.5000 %
# Iteration 34/50 - Covered: 193, Score: 96.5000 %
# Iteration 35/50 - Covered: 193, Score: 96.5000 %
# Iteration 36/50 - Covered: 193, Score: 96.5000 %
# Iteration 37/50 - Covered: 193, Score: 96.5000 %
# Iteration 38/50 - Covered: 193, Score: 96.5000 %
# Iteration 39/50 - Covered: 193, Score: 96.5000 %
# Iteration 40/50 - Covered: 193, Score: 96.5000 %
# Iteration 41/50 - Covered: 193, Score: 96.5000 %
# Iteration 42/50 - Covered: 193, Score: 96.5000 %
# Iteration 43/50 - Covered: 193, Score: 96.5000 %
# Iteration 44/50 - Covered: 193, Score: 96.5000 %
# Iteration 45/50 - Covered: 193, Score: 96.5000 %
# Iteration 46/50 - Covered: 193, Score: 96.5000 %
# Iteration 47/50 - Covered: 193, Score: 96.5000 %
# Iteration 48/50 - Covered: 193, Score: 96.5000 %
# Arrêt anticipé après 48 itérations.
# Optimisation terminée en 0.76 sec - Meilleure couverture: 193, Score final: 96.5000 %
#
#  Exécution de PSO sur scp43.txt...
# Iteration 1/50 - Covered: 195, Score: 97.5000 %
# Iteration 2/50 - Covered: 195, Score: 97.5000 %
# Iteration 3/50 - Covered: 195, Score: 97.5000 %
# Iteration 4/50 - Covered: 195, Score: 97.5000 %
# Iteration 5/50 - Covered: 195, Score: 97.5000 %
# Iteration 6/50 - Covered: 195, Score: 97.5000 %
# Iteration 7/50 - Covered: 195, Score: 97.5000 %
# Iteration 8/50 - Covered: 195, Score: 97.5000 %
# Iteration 9/50 - Covered: 195, Score: 97.5000 %
# Iteration 10/50 - Covered: 195, Score: 97.5000 %
# Iteration 11/50 - Covered: 195, Score: 97.5000 %
# Iteration 12/50 - Covered: 195, Score: 97.5000 %
# Iteration 13/50 - Covered: 195, Score: 97.5000 %
# Iteration 14/50 - Covered: 195, Score: 97.5000 %
# Iteration 15/50 - Covered: 195, Score: 97.5000 %
# Iteration 16/50 - Covered: 195, Score: 97.5000 %
# Iteration 17/50 - Covered: 195, Score: 97.5000 %
# Iteration 18/50 - Covered: 195, Score: 97.5000 %
# Iteration 19/50 - Covered: 195, Score: 97.5000 %
# Iteration 20/50 - Covered: 195, Score: 97.5000 %
# Iteration 21/50 - Covered: 195, Score: 97.5000 %
# Iteration 22/50 - Covered: 195, Score: 97.5000 %
# Iteration 23/50 - Covered: 195, Score: 97.5000 %
# Iteration 24/50 - Covered: 195, Score: 97.5000 %
# Iteration 25/50 - Covered: 195, Score: 97.5000 %
# Iteration 26/50 - Covered: 195, Score: 97.5000 %
# Iteration 27/50 - Covered: 195, Score: 97.5000 %
# Iteration 28/50 - Covered: 196, Score: 98.0000 %
# Iteration 29/50 - Covered: 196, Score: 98.0000 %
# Iteration 30/50 - Covered: 196, Score: 98.0000 %
# Iteration 31/50 - Covered: 196, Score: 98.0000 %
# Iteration 32/50 - Covered: 196, Score: 98.0000 %
# Iteration 33/50 - Covered: 196, Score: 98.0000 %
# Iteration 34/50 - Covered: 196, Score: 98.0000 %
# Iteration 35/50 - Covered: 196, Score: 98.0000 %
# Iteration 36/50 - Covered: 196, Score: 98.0000 %
# Iteration 37/50 - Covered: 196, Score: 98.0000 %
# Iteration 38/50 - Covered: 196, Score: 98.0000 %
# Iteration 39/50 - Covered: 196, Score: 98.0000 %
# Iteration 40/50 - Covered: 196, Score: 98.0000 %
# Iteration 41/50 - Covered: 196, Score: 98.0000 %
# Iteration 42/50 - Covered: 196, Score: 98.0000 %
# Iteration 43/50 - Covered: 196, Score: 98.0000 %
# Iteration 44/50 - Covered: 196, Score: 98.0000 %
# Iteration 45/50 - Covered: 196, Score: 98.0000 %
# Iteration 46/50 - Covered: 196, Score: 98.0000 %
# Iteration 47/50 - Covered: 196, Score: 98.0000 %
# Iteration 48/50 - Covered: 196, Score: 98.0000 %
# Iteration 49/50 - Covered: 196, Score: 98.0000 %
# Iteration 50/50 - Covered: 196, Score: 98.0000 %
# Optimisation terminée en 0.60 sec - Meilleure couverture: 196, Score final: 98.0000 %
#
#  Exécution de PSO sur scp44.txt...
# Iteration 1/50 - Covered: 194, Score: 97.0000 %
# Iteration 2/50 - Covered: 194, Score: 97.0000 %
# Iteration 3/50 - Covered: 194, Score: 97.0000 %
# Iteration 4/50 - Covered: 194, Score: 97.0000 %
# Iteration 5/50 - Covered: 194, Score: 97.0000 %
# Iteration 6/50 - Covered: 194, Score: 97.0000 %
# Iteration 7/50 - Covered: 194, Score: 97.0000 %
# Iteration 8/50 - Covered: 194, Score: 97.0000 %
# Iteration 9/50 - Covered: 194, Score: 97.0000 %
# Iteration 10/50 - Covered: 194, Score: 97.0000 %
# Iteration 11/50 - Covered: 194, Score: 97.0000 %
# Iteration 12/50 - Covered: 194, Score: 97.0000 %
# Iteration 13/50 - Covered: 194, Score: 97.0000 %
# Iteration 14/50 - Covered: 194, Score: 97.0000 %
# Iteration 15/50 - Covered: 194, Score: 97.0000 %
# Iteration 16/50 - Covered: 194, Score: 97.0000 %
# Iteration 17/50 - Covered: 194, Score: 97.0000 %
# Iteration 18/50 - Covered: 194, Score: 97.0000 %
# Iteration 19/50 - Covered: 194, Score: 97.0000 %
# Iteration 20/50 - Covered: 194, Score: 97.0000 %
# Iteration 21/50 - Covered: 194, Score: 97.0000 %
# Iteration 22/50 - Covered: 194, Score: 97.0000 %
# Iteration 23/50 - Covered: 194, Score: 97.0000 %
# Iteration 24/50 - Covered: 194, Score: 97.0000 %
# Iteration 25/50 - Covered: 194, Score: 97.0000 %
# Iteration 26/50 - Covered: 194, Score: 97.0000 %
# Iteration 27/50 - Covered: 194, Score: 97.0000 %
# Iteration 28/50 - Covered: 194, Score: 97.0000 %
# Iteration 29/50 - Covered: 194, Score: 97.0000 %
# Iteration 30/50 - Covered: 194, Score: 97.0000 %
# Iteration 31/50 - Covered: 194, Score: 97.0000 %
# Arrêt anticipé après 31 itérations.
# Optimisation terminée en 0.37 sec - Meilleure couverture: 194, Score final: 97.0000 %
#
#  Exécution de PSO sur scp45.txt...
# Iteration 1/50 - Covered: 196, Score: 98.0000 %
# Iteration 2/50 - Covered: 196, Score: 98.0000 %
# Iteration 3/50 - Covered: 196, Score: 98.0000 %
# Iteration 4/50 - Covered: 196, Score: 98.0000 %
# Iteration 5/50 - Covered: 196, Score: 98.0000 %
# Iteration 6/50 - Covered: 196, Score: 98.0000 %
# Iteration 7/50 - Covered: 196, Score: 98.0000 %
# Iteration 8/50 - Covered: 196, Score: 98.0000 %
# Iteration 9/50 - Covered: 196, Score: 98.0000 %
# Iteration 10/50 - Covered: 196, Score: 98.0000 %
# Iteration 11/50 - Covered: 196, Score: 98.0000 %
# Iteration 12/50 - Covered: 196, Score: 98.0000 %
# Iteration 13/50 - Covered: 196, Score: 98.0000 %
# Iteration 14/50 - Covered: 196, Score: 98.0000 %
# Iteration 15/50 - Covered: 196, Score: 98.0000 %
# Iteration 16/50 - Covered: 196, Score: 98.0000 %
# Iteration 17/50 - Covered: 196, Score: 98.0000 %
# Iteration 18/50 - Covered: 196, Score: 98.0000 %
# Iteration 19/50 - Covered: 196, Score: 98.0000 %
# Iteration 20/50 - Covered: 196, Score: 98.0000 %
# Iteration 21/50 - Covered: 196, Score: 98.0000 %
# Iteration 22/50 - Covered: 196, Score: 98.0000 %
# Iteration 23/50 - Covered: 196, Score: 98.0000 %
# Iteration 24/50 - Covered: 196, Score: 98.0000 %
# Iteration 25/50 - Covered: 196, Score: 98.0000 %
# Iteration 26/50 - Covered: 196, Score: 98.0000 %
# Iteration 27/50 - Covered: 196, Score: 98.0000 %
# Iteration 28/50 - Covered: 196, Score: 98.0000 %
# Iteration 29/50 - Covered: 196, Score: 98.0000 %
# Iteration 30/50 - Covered: 196, Score: 98.0000 %
# Iteration 31/50 - Covered: 196, Score: 98.0000 %
# Arrêt anticipé après 31 itérations.
# Optimisation terminée en 0.37 sec - Meilleure couverture: 196, Score final: 98.0000 %
#
#  Exécution de PSO sur scp46.txt...
# Iteration 1/50 - Covered: 191, Score: 95.5000 %
# Iteration 2/50 - Covered: 192, Score: 96.0000 %
# Iteration 3/50 - Covered: 194, Score: 97.0000 %
# Iteration 4/50 - Covered: 194, Score: 97.0000 %
# Iteration 5/50 - Covered: 194, Score: 97.0000 %
# Iteration 6/50 - Covered: 194, Score: 97.0000 %
# Iteration 7/50 - Covered: 194, Score: 97.0000 %
# Iteration 8/50 - Covered: 194, Score: 97.0000 %
# Iteration 9/50 - Covered: 194, Score: 97.0000 %
# Iteration 10/50 - Covered: 194, Score: 97.0000 %
# Iteration 11/50 - Covered: 194, Score: 97.0000 %
# Iteration 12/50 - Covered: 194, Score: 97.0000 %
# Iteration 13/50 - Covered: 194, Score: 97.0000 %
# Iteration 14/50 - Covered: 194, Score: 97.0000 %
# Iteration 15/50 - Covered: 194, Score: 97.0000 %
# Iteration 16/50 - Covered: 194, Score: 97.0000 %
# Iteration 17/50 - Covered: 194, Score: 97.0000 %
# Iteration 18/50 - Covered: 194, Score: 97.0000 %
# Iteration 19/50 - Covered: 194, Score: 97.0000 %
# Iteration 20/50 - Covered: 194, Score: 97.0000 %
# Iteration 21/50 - Covered: 194, Score: 97.0000 %
# Iteration 22/50 - Covered: 194, Score: 97.0000 %
# Iteration 23/50 - Covered: 194, Score: 97.0000 %
# Iteration 24/50 - Covered: 194, Score: 97.0000 %
# Iteration 25/50 - Covered: 194, Score: 97.0000 %
# Iteration 26/50 - Covered: 194, Score: 97.0000 %
# Iteration 27/50 - Covered: 194, Score: 97.0000 %
# Iteration 28/50 - Covered: 194, Score: 97.0000 %
# Iteration 29/50 - Covered: 194, Score: 97.0000 %
# Iteration 30/50 - Covered: 194, Score: 97.0000 %
# Iteration 31/50 - Covered: 194, Score: 97.0000 %
# Iteration 32/50 - Covered: 194, Score: 97.0000 %
# Iteration 33/50 - Covered: 194, Score: 97.0000 %
# Arrêt anticipé après 33 itérations.
# Optimisation terminée en 0.40 sec - Meilleure couverture: 194, Score final: 97.0000 %
#
#  Exécution de PSO sur scp47.txt...
# Iteration 1/50 - Covered: 194, Score: 97.0000 %
# Iteration 2/50 - Covered: 194, Score: 97.0000 %
# Iteration 3/50 - Covered: 194, Score: 97.0000 %
# Iteration 4/50 - Covered: 195, Score: 97.5000 %
# Iteration 5/50 - Covered: 195, Score: 97.5000 %
# Iteration 6/50 - Covered: 195, Score: 97.5000 %
# Iteration 7/50 - Covered: 195, Score: 97.5000 %
# Iteration 8/50 - Covered: 195, Score: 97.5000 %
# Iteration 9/50 - Covered: 195, Score: 97.5000 %
# Iteration 10/50 - Covered: 195, Score: 97.5000 %
# Iteration 11/50 - Covered: 195, Score: 97.5000 %
# Iteration 12/50 - Covered: 195, Score: 97.5000 %
# Iteration 13/50 - Covered: 195, Score: 97.5000 %
# Iteration 14/50 - Covered: 195, Score: 97.5000 %
# Iteration 15/50 - Covered: 195, Score: 97.5000 %
# Iteration 16/50 - Covered: 195, Score: 97.5000 %
# Iteration 17/50 - Covered: 195, Score: 97.5000 %
# Iteration 18/50 - Covered: 195, Score: 97.5000 %
# Iteration 19/50 - Covered: 195, Score: 97.5000 %
# Iteration 20/50 - Covered: 195, Score: 97.5000 %
# Iteration 21/50 - Covered: 195, Score: 97.5000 %
# Iteration 22/50 - Covered: 195, Score: 97.5000 %
# Iteration 23/50 - Covered: 195, Score: 97.5000 %
# Iteration 24/50 - Covered: 195, Score: 97.5000 %
# Iteration 25/50 - Covered: 195, Score: 97.5000 %
# Iteration 26/50 - Covered: 195, Score: 97.5000 %
# Iteration 27/50 - Covered: 195, Score: 97.5000 %
# Iteration 28/50 - Covered: 195, Score: 97.5000 %
# Iteration 29/50 - Covered: 195, Score: 97.5000 %
# Iteration 30/50 - Covered: 195, Score: 97.5000 %
# Iteration 31/50 - Covered: 195, Score: 97.5000 %
# Iteration 32/50 - Covered: 195, Score: 97.5000 %
# Iteration 33/50 - Covered: 195, Score: 97.5000 %
# Iteration 34/50 - Covered: 195, Score: 97.5000 %
# Arrêt anticipé après 34 itérations.
# Optimisation terminée en 0.33 sec - Meilleure couverture: 195, Score final: 97.5000 %
#
#  Exécution de PSO sur scp48.txt...
# Iteration 1/50 - Covered: 197, Score: 98.5000 %
# Iteration 2/50 - Covered: 197, Score: 98.5000 %
# Iteration 3/50 - Covered: 197, Score: 98.5000 %
# Iteration 4/50 - Covered: 197, Score: 98.5000 %
# Iteration 5/50 - Covered: 197, Score: 98.5000 %
# Iteration 6/50 - Covered: 197, Score: 98.5000 %
# Iteration 7/50 - Covered: 197, Score: 98.5000 %
# Iteration 8/50 - Covered: 197, Score: 98.5000 %
# Iteration 9/50 - Covered: 197, Score: 98.5000 %
# Iteration 10/50 - Covered: 197, Score: 98.5000 %
# Iteration 11/50 - Covered: 197, Score: 98.5000 %
# Iteration 12/50 - Covered: 197, Score: 98.5000 %
# Iteration 13/50 - Covered: 198, Score: 99.0000 %
# Iteration 14/50 - Covered: 198, Score: 99.0000 %
# Iteration 15/50 - Covered: 198, Score: 99.0000 %
# Iteration 16/50 - Covered: 198, Score: 99.0000 %
# Iteration 17/50 - Covered: 198, Score: 99.0000 %
# Iteration 18/50 - Covered: 198, Score: 99.0000 %
# Iteration 19/50 - Covered: 198, Score: 99.0000 %
# Iteration 20/50 - Covered: 198, Score: 99.0000 %
# Iteration 21/50 - Covered: 198, Score: 99.0000 %
# Iteration 22/50 - Covered: 198, Score: 99.0000 %
# Iteration 23/50 - Covered: 198, Score: 99.0000 %
# Iteration 24/50 - Covered: 198, Score: 99.0000 %
# Iteration 25/50 - Covered: 198, Score: 99.0000 %
# Iteration 26/50 - Covered: 198, Score: 99.0000 %
# Iteration 27/50 - Covered: 198, Score: 99.0000 %
# Iteration 28/50 - Covered: 198, Score: 99.0000 %
# Iteration 29/50 - Covered: 198, Score: 99.0000 %
# Iteration 30/50 - Covered: 198, Score: 99.0000 %
# Iteration 31/50 - Covered: 198, Score: 99.0000 %
# Iteration 32/50 - Covered: 198, Score: 99.0000 %
# Iteration 33/50 - Covered: 198, Score: 99.0000 %
# Iteration 34/50 - Covered: 198, Score: 99.0000 %
# Iteration 35/50 - Covered: 198, Score: 99.0000 %
# Iteration 36/50 - Covered: 198, Score: 99.0000 %
# Iteration 37/50 - Covered: 198, Score: 99.0000 %
# Iteration 38/50 - Covered: 198, Score: 99.0000 %
# Iteration 39/50 - Covered: 198, Score: 99.0000 %
# Iteration 40/50 - Covered: 199, Score: 99.5000 %
# Iteration 41/50 - Covered: 199, Score: 99.5000 %
# Iteration 42/50 - Covered: 199, Score: 99.5000 %
# Iteration 43/50 - Covered: 199, Score: 99.5000 %
# Iteration 44/50 - Covered: 199, Score: 99.5000 %
# Iteration 45/50 - Covered: 199, Score: 99.5000 %
# Iteration 46/50 - Covered: 199, Score: 99.5000 %
# Iteration 47/50 - Covered: 199, Score: 99.5000 %
# Iteration 48/50 - Covered: 199, Score: 99.5000 %
# Iteration 49/50 - Covered: 199, Score: 99.5000 %
# Iteration 50/50 - Covered: 199, Score: 99.5000 %
# Optimisation terminée en 0.51 sec - Meilleure couverture: 199, Score final: 99.5000 %
#
#  Exécution de PSO sur scp49.txt...
# Iteration 1/50 - Covered: 192, Score: 96.0000 %
# Iteration 2/50 - Covered: 192, Score: 96.0000 %
# Iteration 3/50 - Covered: 192, Score: 96.0000 %
# Iteration 4/50 - Covered: 192, Score: 96.0000 %
# Iteration 5/50 - Covered: 192, Score: 96.0000 %
# Iteration 6/50 - Covered: 192, Score: 96.0000 %
# Iteration 7/50 - Covered: 192, Score: 96.0000 %
# Iteration 8/50 - Covered: 192, Score: 96.0000 %
# Iteration 9/50 - Covered: 192, Score: 96.0000 %
# Iteration 10/50 - Covered: 192, Score: 96.0000 %
# Iteration 11/50 - Covered: 192, Score: 96.0000 %
# Iteration 12/50 - Covered: 192, Score: 96.0000 %
# Iteration 13/50 - Covered: 192, Score: 96.0000 %
# Iteration 14/50 - Covered: 192, Score: 96.0000 %
# Iteration 15/50 - Covered: 192, Score: 96.0000 %
# Iteration 16/50 - Covered: 192, Score: 96.0000 %
# Iteration 17/50 - Covered: 192, Score: 96.0000 %
# Iteration 18/50 - Covered: 192, Score: 96.0000 %
# Iteration 19/50 - Covered: 192, Score: 96.0000 %
# Iteration 20/50 - Covered: 192, Score: 96.0000 %
# Iteration 21/50 - Covered: 192, Score: 96.0000 %
# Iteration 22/50 - Covered: 192, Score: 96.0000 %
# Iteration 23/50 - Covered: 192, Score: 96.0000 %
# Iteration 24/50 - Covered: 192, Score: 96.0000 %
# Iteration 25/50 - Covered: 192, Score: 96.0000 %
# Iteration 26/50 - Covered: 192, Score: 96.0000 %
# Iteration 27/50 - Covered: 192, Score: 96.0000 %
# Iteration 28/50 - Covered: 192, Score: 96.0000 %
# Iteration 29/50 - Covered: 192, Score: 96.0000 %
# Iteration 30/50 - Covered: 192, Score: 96.0000 %
# Iteration 31/50 - Covered: 192, Score: 96.0000 %
# Arrêt anticipé après 31 itérations.
# Optimisation terminée en 0.31 sec - Meilleure couverture: 192, Score final: 96.0000 %
#
#  Dossier de benchmarks: Benchmark/A
#
#  Exécution de PSO sur scpa1.txt...
# Iteration 1/50 - Covered: 300, Score: 100.0000 %
# Iteration 2/50 - Covered: 300, Score: 100.0000 %
# Iteration 3/50 - Covered: 300, Score: 100.0000 %
# Iteration 4/50 - Covered: 300, Score: 100.0000 %
# Iteration 5/50 - Covered: 300, Score: 100.0000 %
# Iteration 6/50 - Covered: 300, Score: 100.0000 %
# Iteration 7/50 - Covered: 300, Score: 100.0000 %
# Iteration 8/50 - Covered: 300, Score: 100.0000 %
# Iteration 9/50 - Covered: 300, Score: 100.0000 %
# Iteration 10/50 - Covered: 300, Score: 100.0000 %
# Iteration 11/50 - Covered: 300, Score: 100.0000 %
# Iteration 12/50 - Covered: 300, Score: 100.0000 %
# Iteration 13/50 - Covered: 300, Score: 100.0000 %
# Iteration 14/50 - Covered: 300, Score: 100.0000 %
# Iteration 15/50 - Covered: 300, Score: 100.0000 %
# Iteration 16/50 - Covered: 300, Score: 100.0000 %
# Iteration 17/50 - Covered: 300, Score: 100.0000 %
# Iteration 18/50 - Covered: 300, Score: 100.0000 %
# Iteration 19/50 - Covered: 300, Score: 100.0000 %
# Iteration 20/50 - Covered: 300, Score: 100.0000 %
# Iteration 21/50 - Covered: 300, Score: 100.0000 %
# Iteration 22/50 - Covered: 300, Score: 100.0000 %
# Iteration 23/50 - Covered: 300, Score: 100.0000 %
# Iteration 24/50 - Covered: 300, Score: 100.0000 %
# Iteration 25/50 - Covered: 300, Score: 100.0000 %
# Iteration 26/50 - Covered: 300, Score: 100.0000 %
# Iteration 27/50 - Covered: 300, Score: 100.0000 %
# Iteration 28/50 - Covered: 300, Score: 100.0000 %
# Iteration 29/50 - Covered: 300, Score: 100.0000 %
# Iteration 30/50 - Covered: 300, Score: 100.0000 %
# Iteration 31/50 - Covered: 300, Score: 100.0000 %
# Arrêt anticipé après 31 itérations.
# Optimisation terminée en 0.21 sec - Meilleure couverture: 300, Score final: 100.0000 %
#
#  Exécution de PSO sur scpa2.txt...
# Iteration 1/50 - Covered: 299, Score: 99.6667 %
# Iteration 2/50 - Covered: 299, Score: 99.6667 %
# Iteration 3/50 - Covered: 299, Score: 99.6667 %
# Iteration 4/50 - Covered: 299, Score: 99.6667 %
# Iteration 5/50 - Covered: 299, Score: 99.6667 %
# Iteration 6/50 - Covered: 299, Score: 99.6667 %
# Iteration 7/50 - Covered: 299, Score: 99.6667 %
# Iteration 8/50 - Covered: 299, Score: 99.6667 %
# Iteration 9/50 - Covered: 299, Score: 99.6667 %
# Iteration 10/50 - Covered: 299, Score: 99.6667 %
# Iteration 11/50 - Covered: 299, Score: 99.6667 %
# Iteration 12/50 - Covered: 299, Score: 99.6667 %
# Iteration 13/50 - Covered: 299, Score: 99.6667 %
# Iteration 14/50 - Covered: 299, Score: 99.6667 %
# Iteration 15/50 - Covered: 299, Score: 99.6667 %
# Iteration 16/50 - Covered: 299, Score: 99.6667 %
# Iteration 17/50 - Covered: 299, Score: 99.6667 %
# Iteration 18/50 - Covered: 299, Score: 99.6667 %
# Iteration 19/50 - Covered: 299, Score: 99.6667 %
# Iteration 20/50 - Covered: 299, Score: 99.6667 %
# Iteration 21/50 - Covered: 299, Score: 99.6667 %
# Iteration 22/50 - Covered: 299, Score: 99.6667 %
# Iteration 23/50 - Covered: 299, Score: 99.6667 %
# Iteration 24/50 - Covered: 299, Score: 99.6667 %
# Iteration 25/50 - Covered: 299, Score: 99.6667 %
# Iteration 26/50 - Covered: 299, Score: 99.6667 %
# Iteration 27/50 - Covered: 299, Score: 99.6667 %
# Iteration 28/50 - Covered: 299, Score: 99.6667 %
# Iteration 29/50 - Covered: 299, Score: 99.6667 %
# Iteration 30/50 - Covered: 299, Score: 99.6667 %
# Iteration 31/50 - Covered: 299, Score: 99.6667 %
# Arrêt anticipé après 31 itérations.
# Optimisation terminée en 0.21 sec - Meilleure couverture: 299, Score final: 99.6667 %
#
#  Exécution de PSO sur scpa3.txt...
# Iteration 1/50 - Covered: 298, Score: 99.3333 %
# Iteration 2/50 - Covered: 298, Score: 99.3333 %
# Iteration 3/50 - Covered: 298, Score: 99.3333 %
# Iteration 4/50 - Covered: 299, Score: 99.6667 %
# Iteration 5/50 - Covered: 299, Score: 99.6667 %
# Iteration 6/50 - Covered: 299, Score: 99.6667 %
# Iteration 7/50 - Covered: 299, Score: 99.6667 %
# Iteration 8/50 - Covered: 299, Score: 99.6667 %
# Iteration 9/50 - Covered: 299, Score: 99.6667 %
# Iteration 10/50 - Covered: 299, Score: 99.6667 %
# Iteration 11/50 - Covered: 299, Score: 99.6667 %
# Iteration 12/50 - Covered: 299, Score: 99.6667 %
# Iteration 13/50 - Covered: 299, Score: 99.6667 %
# Iteration 14/50 - Covered: 299, Score: 99.6667 %
# Iteration 15/50 - Covered: 299, Score: 99.6667 %
# Iteration 16/50 - Covered: 299, Score: 99.6667 %
# Iteration 17/50 - Covered: 299, Score: 99.6667 %
# Iteration 18/50 - Covered: 299, Score: 99.6667 %
# Iteration 19/50 - Covered: 299, Score: 99.6667 %
# Iteration 20/50 - Covered: 299, Score: 99.6667 %
# Iteration 21/50 - Covered: 299, Score: 99.6667 %
# Iteration 22/50 - Covered: 299, Score: 99.6667 %
# Iteration 23/50 - Covered: 299, Score: 99.6667 %
# Iteration 24/50 - Covered: 299, Score: 99.6667 %
# Iteration 25/50 - Covered: 299, Score: 99.6667 %
# Iteration 26/50 - Covered: 299, Score: 99.6667 %
# Iteration 27/50 - Covered: 299, Score: 99.6667 %
# Iteration 28/50 - Covered: 299, Score: 99.6667 %
# Iteration 29/50 - Covered: 299, Score: 99.6667 %
# Iteration 30/50 - Covered: 299, Score: 99.6667 %
# Iteration 31/50 - Covered: 299, Score: 99.6667 %
# Iteration 32/50 - Covered: 299, Score: 99.6667 %
# Iteration 33/50 - Covered: 299, Score: 99.6667 %
# Iteration 34/50 - Covered: 299, Score: 99.6667 %
# Arrêt anticipé après 34 itérations.
# Optimisation terminée en 0.24 sec - Meilleure couverture: 299, Score final: 99.6667 %
#
#  Exécution de PSO sur scpa4.txt...
# Iteration 1/50 - Covered: 299, Score: 99.6667 %
# Iteration 2/50 - Covered: 299, Score: 99.6667 %
# Iteration 3/50 - Covered: 299, Score: 99.6667 %
# Iteration 4/50 - Covered: 299, Score: 99.6667 %
# Iteration 5/50 - Covered: 300, Score: 100.0000 %
# Iteration 6/50 - Covered: 300, Score: 100.0000 %
# Iteration 7/50 - Covered: 300, Score: 100.0000 %
# Iteration 8/50 - Covered: 300, Score: 100.0000 %
# Iteration 9/50 - Covered: 300, Score: 100.0000 %
# Iteration 10/50 - Covered: 300, Score: 100.0000 %
# Iteration 11/50 - Covered: 300, Score: 100.0000 %
# Iteration 12/50 - Covered: 300, Score: 100.0000 %
# Iteration 13/50 - Covered: 300, Score: 100.0000 %
# Iteration 14/50 - Covered: 300, Score: 100.0000 %
# Iteration 15/50 - Covered: 300, Score: 100.0000 %
# Iteration 16/50 - Covered: 300, Score: 100.0000 %
# Iteration 17/50 - Covered: 300, Score: 100.0000 %
# Iteration 18/50 - Covered: 300, Score: 100.0000 %
# Iteration 19/50 - Covered: 300, Score: 100.0000 %
# Iteration 20/50 - Covered: 300, Score: 100.0000 %
# Iteration 21/50 - Covered: 300, Score: 100.0000 %
# Iteration 22/50 - Covered: 300, Score: 100.0000 %
# Iteration 23/50 - Covered: 300, Score: 100.0000 %
# Iteration 24/50 - Covered: 300, Score: 100.0000 %
# Iteration 25/50 - Covered: 300, Score: 100.0000 %
# Iteration 26/50 - Covered: 300, Score: 100.0000 %
# Iteration 27/50 - Covered: 300, Score: 100.0000 %
# Iteration 28/50 - Covered: 300, Score: 100.0000 %
# Iteration 29/50 - Covered: 300, Score: 100.0000 %
# Iteration 30/50 - Covered: 300, Score: 100.0000 %
# Iteration 31/50 - Covered: 300, Score: 100.0000 %
# Iteration 32/50 - Covered: 300, Score: 100.0000 %
# Iteration 33/50 - Covered: 300, Score: 100.0000 %
# Iteration 34/50 - Covered: 300, Score: 100.0000 %
# Iteration 35/50 - Covered: 300, Score: 100.0000 %
# Arrêt anticipé après 35 itérations.
# Optimisation terminée en 0.28 sec - Meilleure couverture: 300, Score final: 100.0000 %
#
#  Exécution de PSO sur scpa5.txt...
# Iteration 1/50 - Covered: 299, Score: 99.6667 %
# Iteration 2/50 - Covered: 299, Score: 99.6667 %
# Iteration 3/50 - Covered: 299, Score: 99.6667 %
# Iteration 4/50 - Covered: 299, Score: 99.6667 %
# Iteration 5/50 - Covered: 299, Score: 99.6667 %
# Iteration 6/50 - Covered: 299, Score: 99.6667 %
# Iteration 7/50 - Covered: 300, Score: 100.0000 %
# Iteration 8/50 - Covered: 300, Score: 100.0000 %
# Iteration 9/50 - Covered: 300, Score: 100.0000 %
# Iteration 10/50 - Covered: 300, Score: 100.0000 %
# Iteration 11/50 - Covered: 300, Score: 100.0000 %
# Iteration 12/50 - Covered: 300, Score: 100.0000 %
# Iteration 13/50 - Covered: 300, Score: 100.0000 %
# Iteration 14/50 - Covered: 300, Score: 100.0000 %
# Iteration 15/50 - Covered: 300, Score: 100.0000 %
# Iteration 16/50 - Covered: 300, Score: 100.0000 %
# Iteration 17/50 - Covered: 300, Score: 100.0000 %
# Iteration 18/50 - Covered: 300, Score: 100.0000 %
# Iteration 19/50 - Covered: 300, Score: 100.0000 %
# Iteration 20/50 - Covered: 300, Score: 100.0000 %
# Iteration 21/50 - Covered: 300, Score: 100.0000 %
# Iteration 22/50 - Covered: 300, Score: 100.0000 %
# Iteration 23/50 - Covered: 300, Score: 100.0000 %
# Iteration 24/50 - Covered: 300, Score: 100.0000 %
# Iteration 25/50 - Covered: 300, Score: 100.0000 %
# Iteration 26/50 - Covered: 300, Score: 100.0000 %
# Iteration 27/50 - Covered: 300, Score: 100.0000 %
# Iteration 28/50 - Covered: 300, Score: 100.0000 %
# Iteration 29/50 - Covered: 300, Score: 100.0000 %
# Iteration 30/50 - Covered: 300, Score: 100.0000 %
# Iteration 31/50 - Covered: 300, Score: 100.0000 %
# Iteration 32/50 - Covered: 300, Score: 100.0000 %
# Iteration 33/50 - Covered: 300, Score: 100.0000 %
# Iteration 34/50 - Covered: 300, Score: 100.0000 %
# Iteration 35/50 - Covered: 300, Score: 100.0000 %
# Iteration 36/50 - Covered: 300, Score: 100.0000 %
# Iteration 37/50 - Covered: 300, Score: 100.0000 %
# Arrêt anticipé après 37 itérations.
# Optimisation terminée en 0.28 sec - Meilleure couverture: 300, Score final: 100.0000 %
#
#  Dossier de benchmarks: Benchmark/B
#
#  Exécution de PSO sur scpb1.txt...
# Iteration 1/50 - Covered: 300, Score: 100.0000 %
# Iteration 2/50 - Covered: 300, Score: 100.0000 %
# Iteration 3/50 - Covered: 300, Score: 100.0000 %
# Iteration 4/50 - Covered: 300, Score: 100.0000 %
# Iteration 5/50 - Covered: 300, Score: 100.0000 %
# Iteration 6/50 - Covered: 300, Score: 100.0000 %
# Iteration 7/50 - Covered: 300, Score: 100.0000 %
# Iteration 8/50 - Covered: 300, Score: 100.0000 %
# Iteration 9/50 - Covered: 300, Score: 100.0000 %
# Iteration 10/50 - Covered: 300, Score: 100.0000 %
# Iteration 11/50 - Covered: 300, Score: 100.0000 %
# Iteration 12/50 - Covered: 300, Score: 100.0000 %
# Iteration 13/50 - Covered: 300, Score: 100.0000 %
# Iteration 14/50 - Covered: 300, Score: 100.0000 %
# Iteration 15/50 - Covered: 300, Score: 100.0000 %
# Iteration 16/50 - Covered: 300, Score: 100.0000 %
# Iteration 17/50 - Covered: 300, Score: 100.0000 %
# Iteration 18/50 - Covered: 300, Score: 100.0000 %
# Iteration 19/50 - Covered: 300, Score: 100.0000 %
# Iteration 20/50 - Covered: 300, Score: 100.0000 %
# Iteration 21/50 - Covered: 300, Score: 100.0000 %
# Iteration 22/50 - Covered: 300, Score: 100.0000 %
# Iteration 23/50 - Covered: 300, Score: 100.0000 %
# Iteration 24/50 - Covered: 300, Score: 100.0000 %
# Iteration 25/50 - Covered: 300, Score: 100.0000 %
# Iteration 26/50 - Covered: 300, Score: 100.0000 %
# Iteration 27/50 - Covered: 300, Score: 100.0000 %
# Iteration 28/50 - Covered: 300, Score: 100.0000 %
# Iteration 29/50 - Covered: 300, Score: 100.0000 %
# Iteration 30/50 - Covered: 300, Score: 100.0000 %
# Iteration 31/50 - Covered: 300, Score: 100.0000 %
# Arrêt anticipé après 31 itérations.
# Optimisation terminée en 0.24 sec - Meilleure couverture: 300, Score final: 100.0000 %
#
#  Exécution de PSO sur scpb2.txt...
# Iteration 1/50 - Covered: 300, Score: 100.0000 %
# Iteration 2/50 - Covered: 300, Score: 100.0000 %
# Iteration 3/50 - Covered: 300, Score: 100.0000 %
# Iteration 4/50 - Covered: 300, Score: 100.0000 %
# Iteration 5/50 - Covered: 300, Score: 100.0000 %
# Iteration 6/50 - Covered: 300, Score: 100.0000 %
# Iteration 7/50 - Covered: 300, Score: 100.0000 %
# Iteration 8/50 - Covered: 300, Score: 100.0000 %
# Iteration 9/50 - Covered: 300, Score: 100.0000 %
# Iteration 10/50 - Covered: 300, Score: 100.0000 %
# Iteration 11/50 - Covered: 300, Score: 100.0000 %
# Iteration 12/50 - Covered: 300, Score: 100.0000 %
# Iteration 13/50 - Covered: 300, Score: 100.0000 %
# Iteration 14/50 - Covered: 300, Score: 100.0000 %
# Iteration 15/50 - Covered: 300, Score: 100.0000 %
# Iteration 16/50 - Covered: 300, Score: 100.0000 %
# Iteration 17/50 - Covered: 300, Score: 100.0000 %
# Iteration 18/50 - Covered: 300, Score: 100.0000 %
# Iteration 19/50 - Covered: 300, Score: 100.0000 %
# Iteration 20/50 - Covered: 300, Score: 100.0000 %
# Iteration 21/50 - Covered: 300, Score: 100.0000 %
# Iteration 22/50 - Covered: 300, Score: 100.0000 %
# Iteration 23/50 - Covered: 300, Score: 100.0000 %
# Iteration 24/50 - Covered: 300, Score: 100.0000 %
# Iteration 25/50 - Covered: 300, Score: 100.0000 %
# Iteration 26/50 - Covered: 300, Score: 100.0000 %
# Iteration 27/50 - Covered: 300, Score: 100.0000 %
# Iteration 28/50 - Covered: 300, Score: 100.0000 %
# Iteration 29/50 - Covered: 300, Score: 100.0000 %
# Iteration 30/50 - Covered: 300, Score: 100.0000 %
# Iteration 31/50 - Covered: 300, Score: 100.0000 %
# Arrêt anticipé après 31 itérations.
# Optimisation terminée en 0.26 sec - Meilleure couverture: 300, Score final: 100.0000 %
#
#  Exécution de PSO sur scpb3.txt...
# Iteration 1/50 - Covered: 300, Score: 100.0000 %
# Iteration 2/50 - Covered: 300, Score: 100.0000 %
# Iteration 3/50 - Covered: 300, Score: 100.0000 %
# Iteration 4/50 - Covered: 300, Score: 100.0000 %
# Iteration 5/50 - Covered: 300, Score: 100.0000 %
# Iteration 6/50 - Covered: 300, Score: 100.0000 %
# Iteration 7/50 - Covered: 300, Score: 100.0000 %
# Iteration 8/50 - Covered: 300, Score: 100.0000 %
# Iteration 9/50 - Covered: 300, Score: 100.0000 %
# Iteration 10/50 - Covered: 300, Score: 100.0000 %
# Iteration 11/50 - Covered: 300, Score: 100.0000 %
# Iteration 12/50 - Covered: 300, Score: 100.0000 %
# Iteration 13/50 - Covered: 300, Score: 100.0000 %
# Iteration 14/50 - Covered: 300, Score: 100.0000 %
# Iteration 15/50 - Covered: 300, Score: 100.0000 %
# Iteration 16/50 - Covered: 300, Score: 100.0000 %
# Iteration 17/50 - Covered: 300, Score: 100.0000 %
# Iteration 18/50 - Covered: 300, Score: 100.0000 %
# Iteration 19/50 - Covered: 300, Score: 100.0000 %
# Iteration 20/50 - Covered: 300, Score: 100.0000 %
# Iteration 21/50 - Covered: 300, Score: 100.0000 %
# Iteration 22/50 - Covered: 300, Score: 100.0000 %
# Iteration 23/50 - Covered: 300, Score: 100.0000 %
# Iteration 24/50 - Covered: 300, Score: 100.0000 %
# Iteration 25/50 - Covered: 300, Score: 100.0000 %
# Iteration 26/50 - Covered: 300, Score: 100.0000 %
# Iteration 27/50 - Covered: 300, Score: 100.0000 %
# Iteration 28/50 - Covered: 300, Score: 100.0000 %
# Iteration 29/50 - Covered: 300, Score: 100.0000 %
# Iteration 30/50 - Covered: 300, Score: 100.0000 %
# Iteration 31/50 - Covered: 300, Score: 100.0000 %
# Arrêt anticipé après 31 itérations.
# Optimisation terminée en 0.29 sec - Meilleure couverture: 300, Score final: 100.0000 %
#
#  Exécution de PSO sur scpb4.txt...
# Iteration 1/50 - Covered: 300, Score: 100.0000 %
# Iteration 2/50 - Covered: 300, Score: 100.0000 %
# Iteration 3/50 - Covered: 300, Score: 100.0000 %
# Iteration 4/50 - Covered: 300, Score: 100.0000 %
# Iteration 5/50 - Covered: 300, Score: 100.0000 %
# Iteration 6/50 - Covered: 300, Score: 100.0000 %
# Iteration 7/50 - Covered: 300, Score: 100.0000 %
# Iteration 8/50 - Covered: 300, Score: 100.0000 %
# Iteration 9/50 - Covered: 300, Score: 100.0000 %
# Iteration 10/50 - Covered: 300, Score: 100.0000 %
# Iteration 11/50 - Covered: 300, Score: 100.0000 %
# Iteration 12/50 - Covered: 300, Score: 100.0000 %
# Iteration 13/50 - Covered: 300, Score: 100.0000 %
# Iteration 14/50 - Covered: 300, Score: 100.0000 %
# Iteration 15/50 - Covered: 300, Score: 100.0000 %
# Iteration 16/50 - Covered: 300, Score: 100.0000 %
# Iteration 17/50 - Covered: 300, Score: 100.0000 %
# Iteration 18/50 - Covered: 300, Score: 100.0000 %
# Iteration 19/50 - Covered: 300, Score: 100.0000 %
# Iteration 20/50 - Covered: 300, Score: 100.0000 %
# Iteration 21/50 - Covered: 300, Score: 100.0000 %
# Iteration 22/50 - Covered: 300, Score: 100.0000 %
# Iteration 23/50 - Covered: 300, Score: 100.0000 %
# Iteration 24/50 - Covered: 300, Score: 100.0000 %
# Iteration 25/50 - Covered: 300, Score: 100.0000 %
# Iteration 26/50 - Covered: 300, Score: 100.0000 %
# Iteration 27/50 - Covered: 300, Score: 100.0000 %
# Iteration 28/50 - Covered: 300, Score: 100.0000 %
# Iteration 29/50 - Covered: 300, Score: 100.0000 %
# Iteration 30/50 - Covered: 300, Score: 100.0000 %
# Iteration 31/50 - Covered: 300, Score: 100.0000 %
# Arrêt anticipé après 31 itérations.
# Optimisation terminée en 0.31 sec - Meilleure couverture: 300, Score final: 100.0000 %
#
#  Exécution de PSO sur scpb5.txt...
# Iteration 1/50 - Covered: 300, Score: 100.0000 %
# Iteration 2/50 - Covered: 300, Score: 100.0000 %
# Iteration 3/50 - Covered: 300, Score: 100.0000 %
# Iteration 4/50 - Covered: 300, Score: 100.0000 %
# Iteration 5/50 - Covered: 300, Score: 100.0000 %
# Iteration 6/50 - Covered: 300, Score: 100.0000 %
# Iteration 7/50 - Covered: 300, Score: 100.0000 %
# Iteration 8/50 - Covered: 300, Score: 100.0000 %
# Iteration 9/50 - Covered: 300, Score: 100.0000 %
# Iteration 10/50 - Covered: 300, Score: 100.0000 %
# Iteration 11/50 - Covered: 300, Score: 100.0000 %
# Iteration 12/50 - Covered: 300, Score: 100.0000 %
# Iteration 13/50 - Covered: 300, Score: 100.0000 %
# Iteration 14/50 - Covered: 300, Score: 100.0000 %
# Iteration 15/50 - Covered: 300, Score: 100.0000 %
# Iteration 16/50 - Covered: 300, Score: 100.0000 %
# Iteration 17/50 - Covered: 300, Score: 100.0000 %
# Iteration 18/50 - Covered: 300, Score: 100.0000 %
# Iteration 19/50 - Covered: 300, Score: 100.0000 %
# Iteration 20/50 - Covered: 300, Score: 100.0000 %
# Iteration 21/50 - Covered: 300, Score: 100.0000 %
# Iteration 22/50 - Covered: 300, Score: 100.0000 %
# Iteration 23/50 - Covered: 300, Score: 100.0000 %
# Iteration 24/50 - Covered: 300, Score: 100.0000 %
# Iteration 25/50 - Covered: 300, Score: 100.0000 %
# Iteration 26/50 - Covered: 300, Score: 100.0000 %
# Iteration 27/50 - Covered: 300, Score: 100.0000 %
# Iteration 28/50 - Covered: 300, Score: 100.0000 %
# Iteration 29/50 - Covered: 300, Score: 100.0000 %
# Iteration 30/50 - Covered: 300, Score: 100.0000 %
# Iteration 31/50 - Covered: 300, Score: 100.0000 %
# Arrêt anticipé après 31 itérations.
# Optimisation terminée en 0.29 sec - Meilleure couverture: 300, Score final: 100.0000 %
#
#  Dossier de benchmarks: Benchmark/C
#
#  Exécution de PSO sur scpc1.txt...
# Iteration 1/50 - Covered: 400, Score: 100.0000 %
# Iteration 2/50 - Covered: 400, Score: 100.0000 %
# Iteration 3/50 - Covered: 400, Score: 100.0000 %
# Iteration 4/50 - Covered: 400, Score: 100.0000 %
# Iteration 5/50 - Covered: 400, Score: 100.0000 %
# Iteration 6/50 - Covered: 400, Score: 100.0000 %
# Iteration 7/50 - Covered: 400, Score: 100.0000 %
# Iteration 8/50 - Covered: 400, Score: 100.0000 %
# Iteration 9/50 - Covered: 400, Score: 100.0000 %
# Iteration 10/50 - Covered: 400, Score: 100.0000 %
# Iteration 11/50 - Covered: 400, Score: 100.0000 %
# Iteration 12/50 - Covered: 400, Score: 100.0000 %
# Iteration 13/50 - Covered: 400, Score: 100.0000 %
# Iteration 14/50 - Covered: 400, Score: 100.0000 %
# Iteration 15/50 - Covered: 400, Score: 100.0000 %
# Iteration 16/50 - Covered: 400, Score: 100.0000 %
# Iteration 17/50 - Covered: 400, Score: 100.0000 %
# Iteration 18/50 - Covered: 400, Score: 100.0000 %
# Iteration 19/50 - Covered: 400, Score: 100.0000 %
# Iteration 20/50 - Covered: 400, Score: 100.0000 %
# Iteration 21/50 - Covered: 400, Score: 100.0000 %
# Iteration 22/50 - Covered: 400, Score: 100.0000 %
# Iteration 23/50 - Covered: 400, Score: 100.0000 %
# Iteration 24/50 - Covered: 400, Score: 100.0000 %
# Iteration 25/50 - Covered: 400, Score: 100.0000 %
# Iteration 26/50 - Covered: 400, Score: 100.0000 %
# Iteration 27/50 - Covered: 400, Score: 100.0000 %
# Iteration 28/50 - Covered: 400, Score: 100.0000 %
# Iteration 29/50 - Covered: 400, Score: 100.0000 %
# Iteration 30/50 - Covered: 400, Score: 100.0000 %
# Iteration 31/50 - Covered: 400, Score: 100.0000 %
# Arrêt anticipé après 31 itérations.
# Optimisation terminée en 0.39 sec - Meilleure couverture: 400, Score final: 100.0000 %
#
#  Exécution de PSO sur scpc2.txt...
# Iteration 1/50 - Covered: 400, Score: 100.0000 %
# Iteration 2/50 - Covered: 400, Score: 100.0000 %
# Iteration 3/50 - Covered: 400, Score: 100.0000 %
# Iteration 4/50 - Covered: 400, Score: 100.0000 %
# Iteration 5/50 - Covered: 400, Score: 100.0000 %
# Iteration 6/50 - Covered: 400, Score: 100.0000 %
# Iteration 7/50 - Covered: 400, Score: 100.0000 %
# Iteration 8/50 - Covered: 400, Score: 100.0000 %
# Iteration 9/50 - Covered: 400, Score: 100.0000 %
# Iteration 10/50 - Covered: 400, Score: 100.0000 %
# Iteration 11/50 - Covered: 400, Score: 100.0000 %
# Iteration 12/50 - Covered: 400, Score: 100.0000 %
# Iteration 13/50 - Covered: 400, Score: 100.0000 %
# Iteration 14/50 - Covered: 400, Score: 100.0000 %
# Iteration 15/50 - Covered: 400, Score: 100.0000 %
# Iteration 16/50 - Covered: 400, Score: 100.0000 %
# Iteration 17/50 - Covered: 400, Score: 100.0000 %
# Iteration 18/50 - Covered: 400, Score: 100.0000 %
# Iteration 19/50 - Covered: 400, Score: 100.0000 %
# Iteration 20/50 - Covered: 400, Score: 100.0000 %
# Iteration 21/50 - Covered: 400, Score: 100.0000 %
# Iteration 22/50 - Covered: 400, Score: 100.0000 %
# Iteration 23/50 - Covered: 400, Score: 100.0000 %
# Iteration 24/50 - Covered: 400, Score: 100.0000 %
# Iteration 25/50 - Covered: 400, Score: 100.0000 %
# Iteration 26/50 - Covered: 400, Score: 100.0000 %
# Iteration 27/50 - Covered: 400, Score: 100.0000 %
# Iteration 28/50 - Covered: 400, Score: 100.0000 %
# Iteration 29/50 - Covered: 400, Score: 100.0000 %
# Iteration 30/50 - Covered: 400, Score: 100.0000 %
# Iteration 31/50 - Covered: 400, Score: 100.0000 %
# Arrêt anticipé après 31 itérations.
# Optimisation terminée en 0.36 sec - Meilleure couverture: 400, Score final: 100.0000 %
#
#  Exécution de PSO sur scpc3.txt...
# Iteration 1/50 - Covered: 399, Score: 99.7500 %
# Iteration 2/50 - Covered: 399, Score: 99.7500 %
# Iteration 3/50 - Covered: 399, Score: 99.7500 %
# Iteration 4/50 - Covered: 399, Score: 99.7500 %
# Iteration 5/50 - Covered: 399, Score: 99.7500 %
# Iteration 6/50 - Covered: 399, Score: 99.7500 %
# Iteration 7/50 - Covered: 399, Score: 99.7500 %
# Iteration 8/50 - Covered: 399, Score: 99.7500 %
# Iteration 9/50 - Covered: 399, Score: 99.7500 %
# Iteration 10/50 - Covered: 399, Score: 99.7500 %
# Iteration 11/50 - Covered: 399, Score: 99.7500 %
# Iteration 12/50 - Covered: 399, Score: 99.7500 %
# Iteration 13/50 - Covered: 399, Score: 99.7500 %
# Iteration 14/50 - Covered: 399, Score: 99.7500 %
# Iteration 15/50 - Covered: 399, Score: 99.7500 %
# Iteration 16/50 - Covered: 399, Score: 99.7500 %
# Iteration 17/50 - Covered: 399, Score: 99.7500 %
# Iteration 18/50 - Covered: 399, Score: 99.7500 %
# Iteration 19/50 - Covered: 399, Score: 99.7500 %
# Iteration 20/50 - Covered: 399, Score: 99.7500 %
# Iteration 21/50 - Covered: 399, Score: 99.7500 %
# Iteration 22/50 - Covered: 399, Score: 99.7500 %
# Iteration 23/50 - Covered: 399, Score: 99.7500 %
# Iteration 24/50 - Covered: 399, Score: 99.7500 %
# Iteration 25/50 - Covered: 399, Score: 99.7500 %
# Iteration 26/50 - Covered: 399, Score: 99.7500 %
# Iteration 27/50 - Covered: 399, Score: 99.7500 %
# Iteration 28/50 - Covered: 399, Score: 99.7500 %
# Iteration 29/50 - Covered: 399, Score: 99.7500 %
# Iteration 30/50 - Covered: 399, Score: 99.7500 %
# Iteration 31/50 - Covered: 399, Score: 99.7500 %
# Arrêt anticipé après 31 itérations.
# Optimisation terminée en 0.38 sec - Meilleure couverture: 399, Score final: 99.7500 %
#
#  Exécution de PSO sur scpc4.txt...
# Iteration 1/50 - Covered: 400, Score: 100.0000 %
# Iteration 2/50 - Covered: 400, Score: 100.0000 %
# Iteration 3/50 - Covered: 400, Score: 100.0000 %
# Iteration 4/50 - Covered: 400, Score: 100.0000 %
# Iteration 5/50 - Covered: 400, Score: 100.0000 %
# Iteration 6/50 - Covered: 400, Score: 100.0000 %
# Iteration 7/50 - Covered: 400, Score: 100.0000 %
# Iteration 8/50 - Covered: 400, Score: 100.0000 %
# Iteration 9/50 - Covered: 400, Score: 100.0000 %
# Iteration 10/50 - Covered: 400, Score: 100.0000 %
# Iteration 11/50 - Covered: 400, Score: 100.0000 %
# Iteration 12/50 - Covered: 400, Score: 100.0000 %
# Iteration 13/50 - Covered: 400, Score: 100.0000 %
# Iteration 14/50 - Covered: 400, Score: 100.0000 %
# Iteration 15/50 - Covered: 400, Score: 100.0000 %
# Iteration 16/50 - Covered: 400, Score: 100.0000 %
# Iteration 17/50 - Covered: 400, Score: 100.0000 %
# Iteration 18/50 - Covered: 400, Score: 100.0000 %
# Iteration 19/50 - Covered: 400, Score: 100.0000 %
# Iteration 20/50 - Covered: 400, Score: 100.0000 %
# Iteration 21/50 - Covered: 400, Score: 100.0000 %
# Iteration 22/50 - Covered: 400, Score: 100.0000 %
# Iteration 23/50 - Covered: 400, Score: 100.0000 %
# Iteration 24/50 - Covered: 400, Score: 100.0000 %
# Iteration 25/50 - Covered: 400, Score: 100.0000 %
# Iteration 26/50 - Covered: 400, Score: 100.0000 %
# Iteration 27/50 - Covered: 400, Score: 100.0000 %
# Iteration 28/50 - Covered: 400, Score: 100.0000 %
# Iteration 29/50 - Covered: 400, Score: 100.0000 %
# Iteration 30/50 - Covered: 400, Score: 100.0000 %
# Iteration 31/50 - Covered: 400, Score: 100.0000 %
# Arrêt anticipé après 31 itérations.
# Optimisation terminée en 0.39 sec - Meilleure couverture: 400, Score final: 100.0000 %
#
#  Exécution de PSO sur scpc5.txt...
# Iteration 1/50 - Covered: 400, Score: 100.0000 %
# Iteration 2/50 - Covered: 400, Score: 100.0000 %
# Iteration 3/50 - Covered: 400, Score: 100.0000 %
# Iteration 4/50 - Covered: 400, Score: 100.0000 %
# Iteration 5/50 - Covered: 400, Score: 100.0000 %
# Iteration 6/50 - Covered: 400, Score: 100.0000 %
# Iteration 7/50 - Covered: 400, Score: 100.0000 %
# Iteration 8/50 - Covered: 400, Score: 100.0000 %
# Iteration 9/50 - Covered: 400, Score: 100.0000 %
# Iteration 10/50 - Covered: 400, Score: 100.0000 %
# Iteration 11/50 - Covered: 400, Score: 100.0000 %
# Iteration 12/50 - Covered: 400, Score: 100.0000 %
# Iteration 13/50 - Covered: 400, Score: 100.0000 %
# Iteration 14/50 - Covered: 400, Score: 100.0000 %
# Iteration 15/50 - Covered: 400, Score: 100.0000 %
# Iteration 16/50 - Covered: 400, Score: 100.0000 %
# Iteration 17/50 - Covered: 400, Score: 100.0000 %
# Iteration 18/50 - Covered: 400, Score: 100.0000 %
# Iteration 19/50 - Covered: 400, Score: 100.0000 %
# Iteration 20/50 - Covered: 400, Score: 100.0000 %
# Iteration 21/50 - Covered: 400, Score: 100.0000 %
# Iteration 22/50 - Covered: 400, Score: 100.0000 %
# Iteration 23/50 - Covered: 400, Score: 100.0000 %
# Iteration 24/50 - Covered: 400, Score: 100.0000 %
# Iteration 25/50 - Covered: 400, Score: 100.0000 %
# Iteration 26/50 - Covered: 400, Score: 100.0000 %
# Iteration 27/50 - Covered: 400, Score: 100.0000 %
# Iteration 28/50 - Covered: 400, Score: 100.0000 %
# Iteration 29/50 - Covered: 400, Score: 100.0000 %
# Iteration 30/50 - Covered: 400, Score: 100.0000 %
# Iteration 31/50 - Covered: 400, Score: 100.0000 %
# Arrêt anticipé après 31 itérations.
# Optimisation terminée en 0.38 sec - Meilleure couverture: 400, Score final: 100.0000 %
#
#  Résumé des résultats après toutes les exécutions :
# Benchmark/4/scp41.txt: Couvert = 196, Score = 98.0000 % , Temps = 0.63s
# Benchmark/4/scp410.txt: Couvert = 194, Score = 97.0000 % , Temps = 0.40s
# Benchmark/4/scp42.txt: Couvert = 193, Score = 96.5000 % , Temps = 0.76s
# Benchmark/4/scp43.txt: Couvert = 196, Score = 98.0000 % , Temps = 0.60s
# Benchmark/4/scp44.txt: Couvert = 194, Score = 97.0000 % , Temps = 0.37s
# Benchmark/4/scp45.txt: Couvert = 196, Score = 98.0000 % , Temps = 0.37s
# Benchmark/4/scp46.txt: Couvert = 194, Score = 97.0000 % , Temps = 0.40s
# Benchmark/4/scp47.txt: Couvert = 195, Score = 97.5000 % , Temps = 0.33s
# Benchmark/4/scp48.txt: Couvert = 199, Score = 99.5000 % , Temps = 0.51s
# Benchmark/4/scp49.txt: Couvert = 192, Score = 96.0000 % , Temps = 0.31s
# Benchmark/A/scpa1.txt: Couvert = 300, Score = 100.0000 % , Temps = 0.21s
# Benchmark/A/scpa2.txt: Couvert = 299, Score = 99.6667 % , Temps = 0.21s
# Benchmark/A/scpa3.txt: Couvert = 299, Score = 99.6667 % , Temps = 0.24s
# Benchmark/A/scpa4.txt: Couvert = 300, Score = 100.0000 % , Temps = 0.28s
# Benchmark/A/scpa5.txt: Couvert = 300, Score = 100.0000 % , Temps = 0.28s
# Benchmark/B/scpb1.txt: Couvert = 300, Score = 100.0000 % , Temps = 0.24s
# Benchmark/B/scpb2.txt: Couvert = 300, Score = 100.0000 % , Temps = 0.26s
# Benchmark/B/scpb3.txt: Couvert = 300, Score = 100.0000 % , Temps = 0.29s
# Benchmark/B/scpb4.txt: Couvert = 300, Score = 100.0000 % , Temps = 0.31s
# Benchmark/B/scpb5.txt: Couvert = 300, Score = 100.0000 % , Temps = 0.29s
# Benchmark/C/scpc1.txt: Couvert = 400, Score = 100.0000 % , Temps = 0.39s
# Benchmark/C/scpc2.txt: Couvert = 400, Score = 100.0000 % , Temps = 0.36s
# Benchmark/C/scpc3.txt: Couvert = 399, Score = 99.7500 % , Temps = 0.38s
# Benchmark/C/scpc4.txt: Couvert = 400, Score = 100.0000 % , Temps = 0.39s
# Benchmark/C/scpc5.txt: Couvert = 400, Score = 100.0000 % , Temps = 0.38s
